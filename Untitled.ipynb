# %%
# !pip install TTS
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 get_ipython().system('pip install TTS')
# ----> 2 from TTS.api import TTS
#
# ModuleNotFoundError: No module named 'TTS'

# %%
from TTS.api import TTS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from TTS.api import TTS
#
# ModuleNotFoundError: No module named 'TTS'
